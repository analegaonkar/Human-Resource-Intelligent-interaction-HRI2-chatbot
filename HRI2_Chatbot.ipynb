# %%
#!/usr/bin/env python
# coding: utf-8

import nltk
from nltk.stem import WordNetLemmatizer
import json
import pickle
import numpy as np
import random
import nltk
nltk.download('punkt')
nltk.download('wordnet')
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD
lemmatizer = WordNetLemmatizer()

#1. Import and load the data file
words=[]
classes = []
documents = []
ignore_words = ['?', '!']
HRI2_intents_file = open('F:\Symbi Project\A\Human Resources Intelligent Interaction (HRI2)\HRI2_intents.json').read()
HRI2_intents = json.loads(HRI2_intents_file)
#2. Data Preprocessing
for HRI2_intent in HRI2_intents['HRI2_intents']:
    for pattern in HRI2_intent['patterns']:

        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, HRI2_intent['tag']))
        # add to our classes list
        if HRI2_intent['tag'] not in classes:
            classes.append(HRI2_intent['tag'])

# lemmatize, lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and HRI2_intents
print (len(documents), "documents")
# classes = HRI2_intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)

#3. creating a pickle file to store the Python objects which we will use while predicting
pickle.dump(words,open('HRI2_words.pkl','wb'))
pickle.dump(classes,open('HRI2_classes.pkl','wb'))

#4. create our training data
training = []
# create an empty array for our output
output_empty = [0] * len(classes)
# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training, dtype=object)
# create train and test lists. X - patterns, Y - HRI2_intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")

#5. MODEL BUILDING

# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons equal to number of HRI2_intents to predict output HRI2_intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model using Stochastic gradient descent with Nesterov accelerated gradient
sgd = SGD(learning_rate=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#6.fitting and saving the model 
HRI2_model = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('HRI2_model.h5', HRI2_model)

print("Model Created")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# 42 documents
# 9 classes ['HR', 'Leave', 'Name', 'contact', 'goodbye', 'greeting', 'help', 'policy_search', 'thanks']
# 63 unique lemmatized words ["'s", ',', 'a', 'all', 'anyone', 'are', 'awesome', 'be', 'bye', 'called', 'can', 'chatting', 'check', 'contact', 'could', 'day', 'detail', 'do', 'find', 'for', 'give', 'good', 'goodbye', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'hola', 'how', 'hr', 'is', 'later', 'leave', 'list', 'locate', 'me', 'name', 'named', 'next', 'nice', 'of', 'offered', 'open', 'policy', 'provide', 'search', 'see', 'show', 'support', 'thank', 'thanks', 'that', 'there', 'till', 'time', 'to', 'what', 'which', 'who', 'you', 'your']
# Training data created
# Epoch 1/200
# 9/9 [==============================] - 4s 46ms/step - loss: 2.2398 - accuracy: 0.0476
# Epoch 2/200
# 9/9 [==============================] - 0s 3ms/step - loss: 2.2054 - accuracy: 0.0238
# Epoch 3/200
# 9/9 [==============================] - 0s 3ms/step - loss: 2.0995 - accuracy: 0.2619
# Epoch 4/200
# 9/9 [==============================] - 0s 2ms/step - loss: 2.0776 - accuracy: 0.2143
# Epoch 5/200
# 9/9 [==============================] - 0s 2ms/step - loss: 2.0552 - accuracy: 0.2381
# Epoch 6/200
# 9/9 [==============================] - 0s 3ms/step - loss: 1.9631 - accuracy: 0.3095
# Epoch 7/200
# 9/9 [==============================] - 0s 2ms/step - loss: 1.8091 - accuracy: 0.4286
# Epoch 8/200
# 9/9 [==============================] - 0s 2ms/step - loss: 1.6853 - accuracy: 0.4048
# Epoch 9/200
# 9/9 [==============================] - 0s 2ms/step - loss: 1.7419 - accuracy: 0.4762
# Epoch 10/200
# 9/9 [==============================] - 0s 2ms/step - loss: 1.5148 - accuracy: 0.5952
# Epoch 11/200
# 9/9 [==============================] - 0s 2ms/step - loss: 1.5138 - accuracy: 0.5000
# Epoch 12/200
# 9/9 [==============================] - 0s 2ms/step - loss: 1.3482 - accuracy: 0.5238
# Epoch 13/200
# 9/9 [==============================] - 0s 2ms/step - loss: 1.2043 - accuracy: 0.6667
# Epoch 14/200
# 9/9 [==============================] - 0s 2ms/step - loss: 1.1161 - accuracy: 0.7143
# Epoch 15/200
# 9/9 [==============================] - 0s 2ms/step - loss: 1.2948 - accuracy: 0.4524
# Epoch 16/200
# 9/9 [==============================] - 0s 2ms/step - loss: 1.1693 - accuracy: 0.5952
# Epoch 17/200
# 9/9 [==============================] - 0s 2ms/step - loss: 1.0475 - accuracy: 0.6667
# Epoch 18/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.7295 - accuracy: 0.8095
# Epoch 19/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.9181 - accuracy: 0.6667
# Epoch 20/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.7604 - accuracy: 0.7381
# Epoch 21/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.9102 - accuracy: 0.7143
# Epoch 22/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6076 - accuracy: 0.8095
# Epoch 23/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.7866 - accuracy: 0.7857
# Epoch 24/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6133 - accuracy: 0.7857
# Epoch 25/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.5115 - accuracy: 0.8810
# Epoch 26/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.5092 - accuracy: 0.8095
# Epoch 27/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4573 - accuracy: 0.8333
# Epoch 28/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4428 - accuracy: 0.9286
# Epoch 29/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3397 - accuracy: 0.9048
# Epoch 30/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4345 - accuracy: 0.8571
# Epoch 31/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5017 - accuracy: 0.8095
# Epoch 32/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4534 - accuracy: 0.8571
# Epoch 33/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.6032 - accuracy: 0.7857
# Epoch 34/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3885 - accuracy: 0.8810
# Epoch 35/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4983 - accuracy: 0.7857
# Epoch 36/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3483 - accuracy: 0.9524
# Epoch 37/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2889 - accuracy: 0.9286
# Epoch 38/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3342 - accuracy: 0.9286
# Epoch 39/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2319 - accuracy: 0.9286
# Epoch 40/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2054 - accuracy: 0.9762
# Epoch 41/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2430 - accuracy: 0.9286
# Epoch 42/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2042 - accuracy: 0.9524
# Epoch 43/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2939 - accuracy: 0.9048
# Epoch 44/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3372 - accuracy: 0.9048
# Epoch 45/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2080 - accuracy: 0.9762
# Epoch 46/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1996 - accuracy: 0.9762
# Epoch 47/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2587 - accuracy: 0.9048
# Epoch 48/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3186 - accuracy: 0.9048
# Epoch 49/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2053 - accuracy: 0.9286
# Epoch 50/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2014 - accuracy: 0.9286
# Epoch 51/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2100 - accuracy: 0.9286
# Epoch 52/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3451 - accuracy: 0.9286
# Epoch 53/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1915 - accuracy: 0.9048
# Epoch 54/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2228 - accuracy: 0.9524
# Epoch 55/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2220 - accuracy: 0.9524
# Epoch 56/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1698 - accuracy: 0.9524
# Epoch 57/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1020 - accuracy: 0.9762
# Epoch 58/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1072 - accuracy: 0.9524
# Epoch 59/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1289 - accuracy: 0.9762
# Epoch 60/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0855 - accuracy: 1.0000
# Epoch 61/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1697 - accuracy: 0.9524
# Epoch 62/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1122 - accuracy: 1.0000
# Epoch 63/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1671 - accuracy: 0.9524
# Epoch 64/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1208 - accuracy: 0.9762
# Epoch 65/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2564 - accuracy: 0.9286
# Epoch 66/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1235 - accuracy: 0.9762
# Epoch 67/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1513 - accuracy: 0.9762
# Epoch 68/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1067 - accuracy: 0.9762
# Epoch 69/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1868 - accuracy: 0.9524
# Epoch 70/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1260 - accuracy: 0.9762
# Epoch 71/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0988 - accuracy: 0.9524
# Epoch 72/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0612 - accuracy: 1.0000
# Epoch 73/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1105 - accuracy: 0.9762
# Epoch 74/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0899 - accuracy: 0.9762
# Epoch 75/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1001 - accuracy: 0.9762
# Epoch 76/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0741 - accuracy: 1.0000
# Epoch 77/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0493 - accuracy: 1.0000
# Epoch 78/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1112 - accuracy: 0.9762
# Epoch 79/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1453 - accuracy: 0.9524
# Epoch 80/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1463 - accuracy: 0.9762
# Epoch 81/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0562 - accuracy: 1.0000
# Epoch 82/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0305 - accuracy: 1.0000
# Epoch 83/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0573 - accuracy: 1.0000
# Epoch 84/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0644 - accuracy: 0.9762
# Epoch 85/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0587 - accuracy: 1.0000
# Epoch 86/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0927 - accuracy: 0.9524
# Epoch 87/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1027 - accuracy: 0.9762
# Epoch 88/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0695 - accuracy: 0.9762
# Epoch 89/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0765 - accuracy: 1.0000
# Epoch 90/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0900 - accuracy: 0.9762
# Epoch 91/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0455 - accuracy: 1.0000
# Epoch 92/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0566 - accuracy: 1.0000
# Epoch 93/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0966 - accuracy: 0.9762
# Epoch 94/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0476 - accuracy: 0.9762
# Epoch 95/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1411 - accuracy: 0.9762
# Epoch 96/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0803 - accuracy: 0.9762
# Epoch 97/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0339 - accuracy: 1.0000
# Epoch 98/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0482 - accuracy: 0.9762
# Epoch 99/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0279 - accuracy: 1.0000
# Epoch 100/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0379 - accuracy: 0.9762
# Epoch 101/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1440 - accuracy: 0.9524
# Epoch 102/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0455 - accuracy: 1.0000
# Epoch 103/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0810 - accuracy: 1.0000
# Epoch 104/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1411 - accuracy: 0.9762
# Epoch 105/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0487 - accuracy: 1.0000
# Epoch 106/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0187 - accuracy: 1.0000
# Epoch 107/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0252 - accuracy: 1.0000
# Epoch 108/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0330 - accuracy: 1.0000
# Epoch 109/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0326 - accuracy: 1.0000
# Epoch 110/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0605 - accuracy: 0.9762
# Epoch 111/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0119 - accuracy: 1.0000
# Epoch 112/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0268 - accuracy: 1.0000
# Epoch 113/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0467 - accuracy: 1.0000
# Epoch 114/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0938 - accuracy: 0.9524
# Epoch 115/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1059 - accuracy: 0.9762
# Epoch 116/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0883 - accuracy: 0.9762
# Epoch 117/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0393 - accuracy: 1.0000
# Epoch 118/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0380 - accuracy: 1.0000
# Epoch 119/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0476 - accuracy: 1.0000
# Epoch 120/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0666 - accuracy: 0.9762
# Epoch 121/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0509 - accuracy: 0.9762
# Epoch 122/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0703 - accuracy: 1.0000
# Epoch 123/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0185 - accuracy: 1.0000
# Epoch 124/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1428 - accuracy: 0.9524
# Epoch 125/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1369 - accuracy: 0.9762
# Epoch 126/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0862 - accuracy: 0.9762
# Epoch 127/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0801 - accuracy: 0.9762
# Epoch 128/200
# 9/9 [==============================] - ETA: 0s - loss: 9.1143e-04 - accuracy: 1.00 - 0s 2ms/step - loss: 0.0248 - accuracy: 1.0000
# Epoch 129/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0931 - accuracy: 0.9762
# Epoch 130/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0900 - accuracy: 0.9762
# Epoch 131/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0364 - accuracy: 1.0000
# Epoch 132/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0536 - accuracy: 1.0000
# Epoch 133/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0572 - accuracy: 0.9762
# Epoch 134/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0782 - accuracy: 0.9524
# Epoch 135/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0330 - accuracy: 1.0000
# Epoch 136/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0264 - accuracy: 1.0000
# Epoch 137/200
# 9/9 [==============================] - ETA: 0s - loss: 0.0242 - accuracy: 1.00 - 0s 2ms/step - loss: 0.0156 - accuracy: 1.0000
# Epoch 138/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0210 - accuracy: 1.0000
# Epoch 139/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0381 - accuracy: 1.0000
# Epoch 140/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0521 - accuracy: 0.9762
# Epoch 141/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0372 - accuracy: 1.0000
# Epoch 142/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0136 - accuracy: 1.0000
# Epoch 143/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0630 - accuracy: 1.0000
# Epoch 144/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 145/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0212 - accuracy: 1.0000
# Epoch 146/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0726 - accuracy: 0.9524
# Epoch 147/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0176 - accuracy: 1.0000
# Epoch 148/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0181 - accuracy: 1.0000
# Epoch 149/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 150/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0458 - accuracy: 0.9762
# Epoch 151/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0196 - accuracy: 1.0000
# Epoch 152/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0629 - accuracy: 0.9762
# Epoch 153/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0204 - accuracy: 1.0000
# Epoch 154/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0228 - accuracy: 1.0000
# Epoch 155/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0613 - accuracy: 0.9762
# Epoch 156/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0596 - accuracy: 0.9762
# Epoch 157/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0303 - accuracy: 1.0000
# Epoch 158/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0117 - accuracy: 1.0000
# Epoch 159/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 160/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0462 - accuracy: 1.0000
# Epoch 161/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1566 - accuracy: 0.9762
# Epoch 162/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0257 - accuracy: 1.0000
# Epoch 163/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0368 - accuracy: 1.0000
# Epoch 164/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0352 - accuracy: 0.9762
# Epoch 165/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0263 - accuracy: 1.0000
# Epoch 166/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1170 - accuracy: 0.9762
# Epoch 167/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0762 - accuracy: 0.9762
# Epoch 168/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0328 - accuracy: 1.0000
# Epoch 169/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0442 - accuracy: 0.9762
# Epoch 170/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1080 - accuracy: 0.9286
# Epoch 171/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0470 - accuracy: 1.0000
# Epoch 172/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0182 - accuracy: 1.0000
# Epoch 173/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0230 - accuracy: 1.0000
# Epoch 174/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0281 - accuracy: 1.0000
# Epoch 175/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0146 - accuracy: 1.0000
# Epoch 176/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0218 - accuracy: 1.0000
# Epoch 177/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 178/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0190 - accuracy: 1.0000
# Epoch 179/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0170 - accuracy: 1.0000
# Epoch 180/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0522 - accuracy: 0.9762
# Epoch 181/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0826 - accuracy: 0.9762
# Epoch 182/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0513 - accuracy: 1.0000
# Epoch 183/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0615 - accuracy: 1.0000
# Epoch 184/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0239 - accuracy: 1.0000
# Epoch 185/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0443 - accuracy: 0.9762
# Epoch 186/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0315 - accuracy: 1.0000
# Epoch 187/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0364 - accuracy: 0.9762
# Epoch 188/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 189/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0185 - accuracy: 1.0000
# Epoch 190/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0547 - accuracy: 1.0000
# Epoch 191/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0446 - accuracy: 1.0000
# Epoch 192/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0933 - accuracy: 0.9286
# Epoch 193/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 194/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0630 - accuracy: 0.9762
# Epoch 195/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0565 - accuracy: 0.9762
# Epoch 196/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0145 - accuracy: 1.0000
# Epoch 197/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0429 - accuracy: 1.0000
# Epoch 198/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0267 - accuracy: 1.0000
# Epoch 199/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 200/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0196 - accuracy: 1.0000
# Model Created
