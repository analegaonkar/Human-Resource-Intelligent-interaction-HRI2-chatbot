# %%
#!/usr/bin/env python
# coding: utf-8

import nltk
from nltk.stem import WordNetLemmatizer
import json
import pickle
import numpy as np
import random
import nltk
nltk.download('punkt')
nltk.download('wordnet')
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD
lemmatizer = WordNetLemmatizer()

#1. Import and load the data file
words=[]
classes = []
documents = []
ignore_words = ['?', '!']
HRI2_intents_file = open('F:\Symbi Project\A\Human Resources Intelligent Interaction (HRI2)\HRI2_intents.json').read()
HRI2_intents = json.loads(HRI2_intents_file)
#2. Data Preprocessing
for HRI2_intent in HRI2_intents['HRI2_intents']:
    for pattern in HRI2_intent['patterns']:

        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, HRI2_intent['tag']))
        # add to our classes list
        if HRI2_intent['tag'] not in classes:
            classes.append(HRI2_intent['tag'])

# lemmatize, lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and HRI2_intents
print (len(documents), "documents")
# classes = HRI2_intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)

#3. creating a pickle file to store the Python objects which we will use while predicting
pickle.dump(words,open('HRI2_words.pkl','wb'))
pickle.dump(classes,open('HRI2_classes.pkl','wb'))

#4. create our training data
training = []
# create an empty array for our output
output_empty = [0] * len(classes)
# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training, dtype=object)
# create train and test lists. X - patterns, Y - HRI2_intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")

#5. MODEL BUILDING

# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons equal to number of HRI2_intents to predict output HRI2_intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model using Stochastic gradient descent with Nesterov accelerated gradient
sgd = SGD(learning_rate=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#6.fitting and saving the model 
HRI2_model = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('HRI2_model.h5', HRI2_model)

print("Model Created")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# 48 documents
# 10 classes ['adverse_drug', 'blood_pressure', 'blood_pressure_search', 'goodbye', 'greeting', 'hospital_search', 'noanswer', 'options', 'pharmacy_search', 'thanks']
# 89 unique lemmatized words ["'s", ',', 'a', 'adverse', 'all', 'anyone', 'are', 'awesome', 'be', 'behavior', 'blood', 'by', 'bye', 'can', 'causing', 'chatting', 'check', 'could', 'data', 'day', 'detail', 'do', 'dont', 'drug', 'entry', 'find', 'for', 'give', 'good', 'goodbye', 'have', 'hello', 'help', 'helpful', 'helping', 'hewq', 'hey', 'hi', 'history', 'hola', 'hospital', 'how', 'i', 'id', 'is', 'later', 'list', 'load', 'locate', 'log', 'looking', 'lookup', 'management', 'me', 'module', 'nearby', 'next', 'nice', 'of', 'offered', 'open', 'patient', 'pharmacy', 'pressure', 'provide', 'reaction', 'related', 'result', 'search', 'searching', 'see', 'show', 'suitable', 'support', 'task', 'thank', 'thanks', 'that', 'there', 'till', 'time', 'to', 'transfer', 'up', 'want', 'what', 'which', 'with', 'you']
# Training data created
# Epoch 1/200
# 10/10 [==============================] - 1s 2ms/step - loss: 2.2863 - accuracy: 0.1458
# Epoch 2/200
# 10/10 [==============================] - 0s 2ms/step - loss: 2.2771 - accuracy: 0.1042
# Epoch 3/200
# 10/10 [==============================] - 0s 2ms/step - loss: 2.1573 - accuracy: 0.2292
# Epoch 4/200
# 10/10 [==============================] - 0s 3ms/step - loss: 2.1019 - accuracy: 0.3333
# Epoch 5/200
# 10/10 [==============================] - 0s 2ms/step - loss: 2.0034 - accuracy: 0.3750
# Epoch 6/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.7698 - accuracy: 0.4167
# Epoch 7/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.7261 - accuracy: 0.4792
# Epoch 8/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.6936 - accuracy: 0.5000
# Epoch 9/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.2848 - accuracy: 0.7083
# Epoch 10/200
# 10/10 [==============================] - ETA: 0s - loss: 1.7124 - accuracy: 0.20 - 0s 2ms/step - loss: 1.2306 - accuracy: 0.6042
# Epoch 11/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.2320 - accuracy: 0.6875
# Epoch 12/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.0963 - accuracy: 0.6458
# Epoch 13/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.0097 - accuracy: 0.7292
# Epoch 14/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.8763 - accuracy: 0.7708
# Epoch 15/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7700 - accuracy: 0.8125
# Epoch 16/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7961 - accuracy: 0.7917
# Epoch 17/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6453 - accuracy: 0.8542
# Epoch 18/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7246 - accuracy: 0.8333
# Epoch 19/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5878 - accuracy: 0.8125
# Epoch 20/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5075 - accuracy: 0.8958
# Epoch 21/200
# 10/10 [==============================] - ETA: 0s - loss: 1.4064 - accuracy: 0.20 - 0s 3ms/step - loss: 0.6884 - accuracy: 0.7708
# Epoch 22/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5735 - accuracy: 0.8125
# Epoch 23/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5176 - accuracy: 0.8750
# Epoch 24/200
# 10/10 [==============================] - ETA: 0s - loss: 0.9681 - accuracy: 0.60 - 0s 2ms/step - loss: 0.4862 - accuracy: 0.8750
# Epoch 25/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3603 - accuracy: 0.9167
# Epoch 26/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2930 - accuracy: 0.9167
# Epoch 27/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4280 - accuracy: 0.8542
# Epoch 28/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3359 - accuracy: 0.8750
# Epoch 29/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4243 - accuracy: 0.8958
# Epoch 30/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3930 - accuracy: 0.8750
# Epoch 31/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3458 - accuracy: 0.9375
# Epoch 32/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1872 - accuracy: 0.9792
# Epoch 33/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2150 - accuracy: 0.9583
# Epoch 34/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2341 - accuracy: 0.9792
# Epoch 35/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2055 - accuracy: 0.9792
# Epoch 36/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2061 - accuracy: 0.9167
# Epoch 37/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3600 - accuracy: 0.8958
# Epoch 38/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1917 - accuracy: 0.9583
# Epoch 39/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2211 - accuracy: 0.9375
# Epoch 40/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1898 - accuracy: 0.9583
# Epoch 41/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1771 - accuracy: 0.9792
# Epoch 42/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1692 - accuracy: 0.9583
# Epoch 43/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1557 - accuracy: 0.9792
# Epoch 44/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1643 - accuracy: 0.9792
# Epoch 45/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1259 - accuracy: 0.9583
# Epoch 46/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0887 - accuracy: 0.9583
# Epoch 47/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1620 - accuracy: 0.9583
# Epoch 48/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1375 - accuracy: 0.9792
# Epoch 49/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1465 - accuracy: 1.0000
# Epoch 50/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1059 - accuracy: 1.0000
# Epoch 51/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0977 - accuracy: 1.0000
# Epoch 52/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0768 - accuracy: 0.9792
# Epoch 53/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0989 - accuracy: 0.9792
# Epoch 54/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0483 - accuracy: 1.0000
# Epoch 55/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1243 - accuracy: 0.9792
# Epoch 56/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0995 - accuracy: 0.9583
# Epoch 57/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0811 - accuracy: 0.9792
# Epoch 58/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0932 - accuracy: 0.9792
# Epoch 59/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1200 - accuracy: 0.9583
# Epoch 60/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1711 - accuracy: 0.9583
# Epoch 61/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0952 - accuracy: 0.9792
# Epoch 62/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0829 - accuracy: 1.0000
# Epoch 63/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0600 - accuracy: 0.9792
# Epoch 64/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1181 - accuracy: 0.9792
# Epoch 65/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1257 - accuracy: 0.9375
# Epoch 66/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0416 - accuracy: 1.0000
# Epoch 67/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0509 - accuracy: 1.0000
# Epoch 68/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2349 - accuracy: 0.9167
# Epoch 69/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0759 - accuracy: 1.0000
# Epoch 70/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0516 - accuracy: 0.9792
# Epoch 71/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1258 - accuracy: 0.9583
# Epoch 72/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0562 - accuracy: 1.0000
# Epoch 73/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0598 - accuracy: 0.9792
# Epoch 74/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0680 - accuracy: 0.9792
# Epoch 75/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1385 - accuracy: 0.9792
# Epoch 76/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1664 - accuracy: 0.9792
# Epoch 77/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1251 - accuracy: 0.9583
# Epoch 78/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1356 - accuracy: 0.9583
# Epoch 79/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0723 - accuracy: 0.9792
# Epoch 80/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0679 - accuracy: 1.0000
# Epoch 81/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0793 - accuracy: 0.9792
# Epoch 82/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0517 - accuracy: 1.0000
# Epoch 83/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0534 - accuracy: 1.0000
# Epoch 84/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0519 - accuracy: 1.0000
# Epoch 85/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0992 - accuracy: 0.9792
# Epoch 86/200
# 10/10 [==============================] - ETA: 0s - loss: 0.0058 - accuracy: 1.00 - 0s 2ms/step - loss: 0.1071 - accuracy: 0.9583
# Epoch 87/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1112 - accuracy: 0.9583
# Epoch 88/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0737 - accuracy: 1.0000
# Epoch 89/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0776 - accuracy: 0.9792
# Epoch 90/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0448 - accuracy: 1.0000
# Epoch 91/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0812 - accuracy: 0.9583
# Epoch 92/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0649 - accuracy: 0.9792
# Epoch 93/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0345 - accuracy: 1.0000
# Epoch 94/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0589 - accuracy: 0.9792
# Epoch 95/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2032 - accuracy: 0.9792
# Epoch 96/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0497 - accuracy: 1.0000
# Epoch 97/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0394 - accuracy: 1.0000
# Epoch 98/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1002 - accuracy: 0.9583
# Epoch 99/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0307 - accuracy: 1.0000
# Epoch 100/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0691 - accuracy: 0.9792
# Epoch 101/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0609 - accuracy: 1.0000
# Epoch 102/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0397 - accuracy: 1.0000
# Epoch 103/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0337 - accuracy: 1.0000
# Epoch 104/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0476 - accuracy: 1.0000
# Epoch 105/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0208 - accuracy: 1.0000
# Epoch 106/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0298 - accuracy: 1.0000
# Epoch 107/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1046 - accuracy: 0.9375
# Epoch 108/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0415 - accuracy: 1.0000
# Epoch 109/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0618 - accuracy: 0.9792
# Epoch 110/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0706 - accuracy: 0.9792
# Epoch 111/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0527 - accuracy: 0.9792
# Epoch 112/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0383 - accuracy: 1.0000
# Epoch 113/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0820 - accuracy: 0.9583
# Epoch 114/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0319 - accuracy: 1.0000
# Epoch 115/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0138 - accuracy: 1.0000
# Epoch 116/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0166 - accuracy: 1.0000
# Epoch 117/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0643 - accuracy: 1.0000
# Epoch 118/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0220 - accuracy: 1.0000
# Epoch 119/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0622 - accuracy: 0.9792
# Epoch 120/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0207 - accuracy: 1.0000
# Epoch 121/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0284 - accuracy: 1.0000
# Epoch 122/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0782 - accuracy: 0.9792
# Epoch 123/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1102 - accuracy: 0.9792
# Epoch 124/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0217 - accuracy: 1.0000
# Epoch 125/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0469 - accuracy: 1.0000
# Epoch 126/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0406 - accuracy: 0.9792
# Epoch 127/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0704 - accuracy: 0.9583
# Epoch 128/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0177 - accuracy: 1.0000
# Epoch 129/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0155 - accuracy: 1.0000
# Epoch 130/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0306 - accuracy: 1.0000
# Epoch 131/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0753 - accuracy: 0.9792
# Epoch 132/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0555 - accuracy: 0.9792
# Epoch 133/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0281 - accuracy: 1.0000
# Epoch 134/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0251 - accuracy: 1.0000
# Epoch 135/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0191 - accuracy: 1.0000
# Epoch 136/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 137/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0220 - accuracy: 1.0000
# Epoch 138/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0180 - accuracy: 1.0000
# Epoch 139/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1360 - accuracy: 0.9583
# Epoch 140/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 141/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0445 - accuracy: 1.0000
# Epoch 142/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0315 - accuracy: 1.0000
# Epoch 143/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0166 - accuracy: 1.0000
# Epoch 144/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0272 - accuracy: 1.0000
# Epoch 145/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0418 - accuracy: 1.0000
# Epoch 146/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0233 - accuracy: 1.0000
# Epoch 147/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 148/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0232 - accuracy: 1.0000
# Epoch 149/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0315 - accuracy: 1.0000
# Epoch 150/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0494 - accuracy: 0.9792
# Epoch 151/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0174 - accuracy: 1.0000
# Epoch 152/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0846 - accuracy: 0.9792
# Epoch 153/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0585 - accuracy: 0.9792
# Epoch 154/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0581 - accuracy: 0.9792
# Epoch 155/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 156/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 157/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0346 - accuracy: 1.0000
# Epoch 158/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0209 - accuracy: 1.0000
# Epoch 159/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0664 - accuracy: 0.9792
# Epoch 160/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0683 - accuracy: 0.9583
# Epoch 161/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0211 - accuracy: 1.0000
# Epoch 162/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0180 - accuracy: 1.0000
# Epoch 163/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0253 - accuracy: 1.0000
# Epoch 164/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1293 - accuracy: 0.9583
# Epoch 165/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0324 - accuracy: 0.9792
# Epoch 166/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0469 - accuracy: 0.9792
# Epoch 167/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0318 - accuracy: 0.9792
# Epoch 168/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0259 - accuracy: 1.0000
# Epoch 169/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0225 - accuracy: 1.0000
# Epoch 170/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 171/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0139 - accuracy: 1.0000
# Epoch 172/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0387 - accuracy: 1.0000
# Epoch 173/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0386 - accuracy: 0.9792
# Epoch 174/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0390 - accuracy: 0.9792
# Epoch 175/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0542 - accuracy: 0.9792
# Epoch 176/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0622 - accuracy: 0.9792
# Epoch 177/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0446 - accuracy: 0.9792
# Epoch 178/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0414 - accuracy: 1.0000
# Epoch 179/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0807 - accuracy: 0.9792
# Epoch 180/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0270 - accuracy: 1.0000
# Epoch 181/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0363 - accuracy: 1.0000
# Epoch 182/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0408 - accuracy: 0.9792
# Epoch 183/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0207 - accuracy: 1.0000
# Epoch 184/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0196 - accuracy: 1.0000
# Epoch 185/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0301 - accuracy: 0.9792
# Epoch 186/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0565 - accuracy: 0.9792
# Epoch 187/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0262 - accuracy: 1.0000
# Epoch 188/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0216 - accuracy: 1.0000
# Epoch 189/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0997 - accuracy: 0.9792
# Epoch 190/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0227 - accuracy: 1.0000
# Epoch 191/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0212 - accuracy: 1.0000
# Epoch 192/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 193/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 194/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0233 - accuracy: 1.0000
# Epoch 195/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0211 - accuracy: 1.0000
# Epoch 196/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0203 - accuracy: 1.0000
# Epoch 197/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 198/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 199/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0572 - accuracy: 0.9792
# Epoch 200/200
# 10/10 [==============================] - 0s 889us/step - loss: 0.0067 - accuracy: 1.0000
# Model Created
